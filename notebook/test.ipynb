# %%
import os
os.chdir('/content/IMDB_Reviews')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import os
# ----> 2 os.chdir('/content/IMDB_Reviews')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/IMDB_Reviews'

# %%
import sys
import os
import sys
sys.path.append("/content/IMDB_Reviews/src")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from preprocessing import load_data
from train_ml import train_ml_model
from train_dl import train_dl_model
from predict import predict_sentiment
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
#
#                                         clean_review  label
# 0  one reviewers mentioned watching 1 oz episode ...      1

# %%
df=load_data()
df.head(1)
# Out:
# ML Accuracy: 0.8971

# %%
ml_model = train_ml_model(df)

# %%
train_dl_model(df)

# %%
text="Good one"
predict_sentiment(text)
